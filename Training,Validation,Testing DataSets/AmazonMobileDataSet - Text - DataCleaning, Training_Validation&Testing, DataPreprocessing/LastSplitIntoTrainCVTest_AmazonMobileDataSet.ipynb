# %%
import pandas as pd
import re
from nltk.corpus import stopwords
import string
from nltk.stem.snowball import SnowballStemmer

import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %%
# Reading the data file into a DATAFRAME and checking the shape 
data=pd.read_csv('35.1AmazonMobileDataUncleaned.csv')
print(data.shape)
# Out:
# (71922, 2)

# %% [markdown]
# # Data Cleaning(Text)

# %%
def datapreprocess(sen):
    
    sen = re.sub(r"didn't", "did not", sen)
    sen = re.sub(r"don't", "do not", sen)
    sen = re.sub(r"won't", "will not", sen)
    sen = re.sub(r"can't", "can not", sen)
    sen = re.sub(r"wasn't", "was not", sen)
    sen = re.sub(r"\'ve", " have", sen)
    sen = re.sub(r"\'m", " am", sen)
    sen = re.sub(r"\'ll", " will", sen)
    sen = re.sub(r"\'re", " are", sen)
    sen = re.sub(r"\'s", " is", sen)
    sen = re.sub(r"\'d", " would", sen)
    sen = re.sub(r"\'t", " not", sen)
    sen = re.sub(r"\'m", " am", sen)
    
    
    p = set(string.punctuation) # p take all the punctuations, punctuations displayed below
    sen=sen.lower() # convert text to lower case
    words=sen.split() # split the text into words
    ctext=[]
    for i in range(10): #adding numbers from 0 - 9 to p 
        p.add(str(i))
    for i in words:
        t=''.join([x for x in i.encode("ascii","ignore").decode("ascii") if x not in p]) # ignoring non ascii charecters and numbers
        ctext.append(t)
    return " ".join([i for i in ctext]) # joining the cleaned words to text
    
    

stop=set(stopwords.words('english'))
print(stop)
stop.remove('no')
stop.remove('not')
stop.remove('nor')

preprocessed_essays = []
for sentance in data['uncleanedreview'].values:
    try:
        ctxt=datapreprocess(str(sentance))
        if len(ctxt)==0: raise()
        ctxt = ' '.join(e for e in ctxt.split() if e not in stop)
        preprocessed_essays.append(ctxt.lower().strip())
    except:
        preprocessed_essays.append("NAN")  
data['cleanedtext'] = preprocessed_essays
data.drop(data[data["cleanedtext"]=="NAN"].index,axis = 0,inplace = True) # deleting rows that have no text 
data=data.reset_index(drop='true') # after deleting rows index should be reset
data['decision']= data['decision'].replace('positive',1)
data['decision']= data['decision'].replace('negative',0)


s = SnowballStemmer("english")
p=[]
for i in data['cleanedtext'].values:
    k=[]
    for word in i.split():
        k.append(s.stem(word))
    l=' '.join(k)
    p.append(l)

data['finaltext']=p

data.to_csv (r'AmazonMobileDataCleaned.csv')
# Out:
# {'she', 'them', 'over', 'should', 'he', 'ain', 'her', 'these', 'into', 'all', 'd', 'yours', "wasn't", 'between', 'is', 'herself', 'for', 'which', "hasn't", 'whom', "should've", 'no', 'ourselves', 'we', 'few', 'a', 'doesn', 'further', 'me', 'most', "she's", 'him', 'am', 't', 'ours', 'there', 'shouldn', 'wasn', 'haven', 'themselves', 'don', 'they', 'then', "doesn't", 'hadn', 'of', 'both', 'your', 'won', 'again', 'during', 'from', 'here', 'had', "won't", 'myself', 'who', 'have', 'up', 'did', 'but', 'so', 'to', 'on', "you're", 'are', 'those', 'not', 'couldn', 's', "aren't", 'o', 'more', 'the', 'i', "mustn't", 'was', 'until', "couldn't", 'once', 'y', "hadn't", 'out', 'didn', 'theirs', "haven't", 'now', 'ma', 'just', 'some', "you'll", 're', "you'd", 'wouldn', 'it', 'their', 'when', 'in', 'be', 'yourselves', 'will', 'our', 'been', 'any', 'where', 'and', 'by', "shouldn't", "you've", 'off', 'll', 'own', 'this', 'against', 'were', 'having', 'you', 'what', 'do', 'an', 'that', 'isn', 'too', 'through', "shan't", "it's", 've', 'his', 'because', "wouldn't", 'needn', 'about', 'other', "didn't", 'if', "isn't", 'm', 'each', 'such', 'with', "weren't", 'same', 'does', 'itself', 'being', 'very', 'down', 'while', 'nor', 'hasn', 'mustn', 'under', "don't", 'at', 'shan', 'has', "mightn't", 'as', "that'll", 'only', 'before', 'below', 'or', 'can', 'than', 'doing', 'why', 'weren', "needn't", 'after', 'mightn', 'how', 'aren', 'my', 'hers', 'himself', 'yourself', 'above', 'its'}

# %% [markdown]
# # Data Preprocessing

# %%
data=pd.read_csv('AmazonMobileDataCleaned.csv')

from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer(min_df=10,ngram_range=(1,4))
vec.fit(data['finaltext'].values) # fit has to happen only on train data


data_preprocessed = vec.transform(data['finaltext'].values)


print("After vectorizations")
print(data_preprocessed.shape)
print(vec.get_feature_names())
# Out:
# After vectorizations
# (71922, 39315)
# ['aa', 'abandon', 'abe', 'abil', 'abil add', 'abil connect', 'abil phone', 'abil take', 'abil use', 'abl', 'abl access', 'abl activ', 'abl activ phone', 'abl add', 'abl buy', 'abl call', 'abl captur', 'abl chang', 'abl charg', 'abl charg phone', 'abl connect', 'abl contact', 'abl custom', 'abl disabl', 'abl download', 'abl easili', 'abl figur', 'abl find', 'abl fix', 'abl get', 'abl get phone', 'abl get work', 'abl give', 'abl go', 'abl handl', 'abl hear', 'abl help', 'abl keep', 'abl make', 'abl make call', 'abl make phone', 'abl make receiv', 'abl move', 'abl notic', 'abl phone', 'abl pick', 'abl play', 'abl purchas', 'abl put', 'abl receiv', 'abl regist', 'abl remov', 'abl replac', 'abl return', 'abl run', 'abl see', 'abl send', 'abl send receiv', 'abl set', 'abl switch', 'abl sync', 'abl take', 'abl tell', 'abl text', 'abl transfer', 'abl turn', 'abl uninstal', 'abl unlock', 'abl updat', 'abl upgrad', 'abl use', 'abl use phone', 'abl work', 'abl write', 'abnorm', 'abomin', 'abroad', 'abrupt', 'absenc', 'absolut', 'absolut amaz', 'absolut amaz phone', 'absolut awesom', 'absolut beauti', 'absolut best', 'absolut best phone', 'absolut best phone ever', 'absolut buy', 'absolut fantast', 'absolut flawless', 'absolut garbag', 'absolut gorgeous', 'absolut great', 'absolut hate', 'absolut horribl', 'absolut incred', 'absolut love', 'absolut love new', 'absolut love new phone', 'absolut love no', 'absolut love phone', 'absolut need', 'absolut no', 'absolut no complaint', 'absolut no issu', 'absolut no problem', 'absolut not', 'absolut noth', 'absolut perfect', 'absolut perfect condit', 'absolut recommend', 'absolut stun', 'absolut terribl', 'absolut wonder', 'absolut worst', 'absolut worth', 'absorb', 'absurd', 'abus', 'abus phone', 'abysm', 'ac', 'ac adapt', 'acceleromet', 'accent', 'accept', 'accept call', 'accept condit', 'accept not', 'accept phone', 'accept return', 'accept sim', 'accept sim card', 'accesori', 'accesorio', 'access', 'access app', 'access batteri', 'access camera', 'access contact', 'access data', 'access everyth', 'access featur', 'access internet', 'access phone', 'access point', 'access point name', 'access set', 'access sim', 'access wifi', 'accessori', 'accessori avail', 'accessori came', 'accessori includ', 'accessori like', 'accessori no', 'accessori not', 'accessori phone', 'accessori work', 'accessori would', 'accid', 'accident', 'accident drop', 'accident drop phone', 'accident hit', 'accident press', 'accident push', 'accident touch', 'acclim', 'accommod', 'accompani', 'accomplish', 'accord', 'accord samsung', 'account', 'account no', 'account not', 'account phone', 'account use', 'acct', 'accubatteri', 'accur', 'accuraci', 'accustom', 'ace', 'achiev', 'acknowledg', 'acquaint', 'acquir', 'across', 'across board', 'across phone', 'across room', 'across screen', 'act', 'act brand', 'act brand new', 'act like', 'act like brand', 'act like brand new', 'act like new', 'action', 'action shot', 'activ', 'activ account', 'activ activ', 'activ also', 'activ app', 'activ att', 'activ batteri', 'activ button', 'activ call', 'activ camera', 'activ carrier', 'activ devic', 'activ display', 'activ easi', 'activ edg', 'activ fee', 'activ great', 'activ metro', 'activ network', 'activ new', 'activ new phone', 'activ no', 'activ no problem', 'activ not', 'activ one', 'activ onlin', 'activ phone', 'activ phone not', 'activ phone phone', 'activ phone sprint', 'activ phone verizon', 'activ process', 'activ screen', 'activ servic', 'activ sim', 'activ sim card', 'activ sinc', 'activ sprint', 'activ straight', 'activ straight talk', 'activ tmobil', 'activ told', 'activ tri', 'activ two', 'activ use', 'activ verizon', 'activ verizon network', 'activ without', 'activ work', 'activ would', 'activ yet', 'actual', 'actual better', 'actual bought', 'actual call', 'actual came', 'actual camera', 'actual charg', 'actual easier', 'actual feel', 'actual get', 'actual good', 'actual got', 'actual like', 'actual look', 'actual love', ...

# %% [markdown]
# # Data splitting into train,validaion&test datasets

# %%
label = data['decision'].values #output
feedback = data_preprocessed #inputs


from sklearn.model_selection import train_test_split
inputtrain, inputtest, outputtrain, outputtest = train_test_split(feedback, label, test_size=0.20, stratify=label)
inputtrain, inputcv, outputtrain, outputcv = train_test_split(inputtrain, outputtrain, test_size=0.20, stratify=outputtrain)
print(inputtrain.shape)
print(inputcv.shape)
print(inputtest.shape)
print(outputtrain.shape)
print(outputcv.shape)
print(outputtest.shape)
# Out:
# (46029, 39315)
# (11508, 39315)
# (14385, 39315)
# (46029,)
# (11508,)
# (14385,)

# %% [markdown]
# # Data Preprocessing on Training,CV&Testing datasets

# %%
#fit() applied only on inputtrain datasets, transform() applied on inputtrain,inputtest,inputcv datasets
#fit() & transform() applied on each & every column(features). Here we have only one column 'finaltext'

# %%
data_preprocessed.shape
# Out:
# (71922, 39315)

# %%
data['decision'].values.shape
# Out:
# (71922,)
